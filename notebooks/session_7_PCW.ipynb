# %%
import pandas as pd
import numpy as np
import string as str
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_excel ("/content/S7_PCW-Market_Research_Dataset.xlsx")

df.head()
# Out:
#    Respondent_ID Age_Group      Gender Preferred_Shopping_Channel  \
# 0              1     45-54        Male                   In-Store
# 1              2       55+  Non-binary                     Online
# 2              3     35-44      Female                   In-Store
# 3              4       55+        Male                     Online
# 4              5       55+        Male                       Both
#
#   Product_Category Satisfaction_Level
# 0      Electronics          Satisfied
# 1             Home  Very Dissatisfied
# 2           Beauty  Very Dissatisfied
# 3             Home  Very Dissatisfied
# 4      Electronics            Neutral

# %%
category_counts = df["Product_Category"].value_counts()
total_responses = len(df)
print(category_counts)
print(total_responses)
# Out:
# Product_Category
# Home           34
# Clothing       32
# Electronics    30
# Beauty         30
# Groceries      24
# Name: count, dtype: int64
# 150

# %%
category_probabilities = category_counts / total_responses
print(category_probabilities)
# Out:
# Product_Category
# Home           0.226667
# Clothing       0.213333
# Electronics    0.200000
# Beauty         0.200000
# Groceries      0.160000
# Name: count, dtype: float64

# %%
channel_counts = df["Preferred_Shopping_Channel"].value_counts()
total_responses = len(df)
prob_online = channel_counts["Online"] / total_responses
print("Probabilidad de que un cliente prefiera comprar online:", prob_online)
# Out:
# Probabilidad de que un cliente prefiera comprar online: 0.3466666666666667

# %%
prob_very_satisfied = len(online_shoppers[online_shoppers["Satisfaction_Level"] == "Very Satisfied"]) / len(online_shoppers)
print(prob_very_satisfied)
# Out:
# 0.1346153846153846

# %%
import matplotlib.pyplot as plt
category_counts.plot(kind="bar")
plt.xlabel("Product Category")
plt.ylabel("Frequency")
plt.title("Product Category Preferences")
plt.show()
